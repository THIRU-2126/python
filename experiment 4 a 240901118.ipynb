# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
               columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  1.510976 -1.068763  0.791991
# b       NaN       NaN       NaN
# c -0.257534  0.439129  0.487691
# d  0.224205 -0.605503 -1.975319
# e       NaN       NaN       NaN
# f -1.577533  1.109917  0.499243
#
#
# Dropped DataFrame
#          one       two     three
# a  1.510976 -1.068763  0.791991
# c -0.257534  0.439129  0.487691
# d  0.224205 -0.605503 -1.975319
# f -1.577533  1.109917  0.499243

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
               columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with'0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.750115  0.549016  0.038110
# b       NaN       NaN       NaN
# c  0.444923 -0.561933  0.391081
#
#
# NaN replaced with'0':
#
#         one       two     three
# a  0.750115  0.549016  0.038110
# b  0.000000  0.000000  0.000000
# c  0.444923 -0.561933  0.391081

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
                'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
               columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a -1.265739 -0.245765  0.347340
# b       NaN       NaN       NaN
# c -0.173022 -0.510790  1.991125
# d -0.505215 -1.614532  1.064424
# e       NaN       NaN       NaN
# f  0.452760 -0.562552 -0.772188
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
               columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("nNaN-Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.183687 -0.126216 -1.153790
# b       NaN       NaN       NaN
# c -1.642709 -0.654268  0.197204
# d  0.146499  0.624136  0.295098
# e       NaN       NaN       NaN
# f  0.153804  0.266148  0.245265
# nNaN-Filled with Background values:
#
#         one       two     three
# a  0.183687 -0.126216 -1.153790
# b -1.642709 -0.654268  0.197204
# c -1.642709 -0.654268  0.197204
# d  0.146499  0.624136  0.295098
# e  0.153804  0.266148  0.245265
# f  0.153804  0.266148  0.245265
